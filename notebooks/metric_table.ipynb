# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Global Variables
PATH_TO_RESULTS = "../results/"

MODEL_LIST = [
    "training_simple/BinaryClassifier_20250522_101858.csv",
    "training_simple/BinaryClassifier_20250522_143030_finetuned.csv",
    "train_normal_test_on_shuffled/BinaryClassifier_20250522_144429_shuffled_text.csv",
    "train_normal_test_on_shuffled/BinaryClassifier_20250522_145305_shuffled_image.csv",
    "train_normal_test_on_shuffled/BinaryClassifier_20250522_150106_finetuned_shuffled_text.csv",
    "train_normal_test_on_shuffled/BinaryClassifier_20250522_151513_finetuned_shuffled_image.csv",
    "robust_training/BinaryClassifier-20250522_101858_20250522_180923_shuffled_text_test_normal.csv",
    "robust_training/BinaryClassifier-20250522_101858_20250522_181629_shuffled_text_test_shuffled_text.csv",
    "robust_training/BinaryClassifier-20250522_101858_20250522_183542_shuffled_image_test_normal.csv",
    "robust_training/BinaryClassifier-20250522_101858_20250522_184658_shuffled_image_test_shuffled_image.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250522_191950_finetuned_shuffled_text_test_normal.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250522_204844_finetuned_shuffled_text_test_shuffled_text.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250522_213324_finetuned_shuffled_image_test_normal.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250523_055956_finetuned_shuffled_image_test_shuffled_image.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250523_115323_finetuned_shuffled_text_test_shuffled_image.csv",
    "robust_training/BinaryClassifier-20250522_143030_20250527_073503_finetuned_shuffled_images_test_shuffled_text.csv"
]

LABEL_LIST = [
    "Binary Classifier Trained/Tested Simple",
    "Finetuned Binary Classifier Trained/Tested Simple",
    "Binary Classifier Trained Simple/Tested on Shuffled Text",
    "Binary Classifier Trained Simple/Tested on Shuffled Image",
    "Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text",
    "Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image",
    "Binary Classifier Trained on Shuffled Text/Tested on Normal Data",
    "Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text",
    "Binary Classifier Trained on Shuffled Image/Tested on Normal Data",
    "Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image",
    "Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data",
    "Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text",
    "Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data",
    "Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image",
    "Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image",
    "Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text"
]

SHORT_LABEL_LIST = [
    "Base",
    "Finetuned",
    "Base",
    "Base",
    "Finetuned",
    "Finetuned",
    "Robust Base",
    "Robust Base",
    "Robust Base",
    "Robust Base",
    "Robust Finetuned",
    "Robust Finetuned",
    "Robust Finetuned",
    "Robust Finetuned",
    "Robust Finetuned",
    "Robust Finetuned"
]

TEST_DATA_LABEL = [
    "Normal Test Data",
    "Normal Test Data",
    "Shuffled Text",
    "Shuffled Image",
    "Shuffled Text",
    "Shuffled Image",
    "Normal Test Data",
    "Shuffled Text",
    "Normal Test Data",
    "Shuffled Image",
    "Normal Test Data",
    "Shuffled Text",
    "Normal Test Data",
    "Shuffled Image",
    "Shuffled Image",
    "Shuffled Text"  
]

TRAINING_DATA_LABEL = [
    "Normal TRAIN Data",
    "Normal TRAIN Data",
    "Normal TRAIN Data",
    "Normal TRAIN Data",
    "Normal TRAIN Data",
    "Normal TRAIN Data",
    "Shuffled Text",
    "Shuffled Text",
    "Shuffled Image",
    "Shuffled Image",
    "Shuffled Text",
    "Shuffled Text",
    "Shuffled Image",
    "Shuffled Image",
    "Shuffled Text",
    "Shuffled Images"
]

# %%
def calculate_summary_stat(
        metric: str,
        path_to_results = PATH_TO_RESULTS,
        model_list = MODEL_LIST,
        label_list = LABEL_LIST,
        training_data_label = TRAINING_DATA_LABEL,
        test_data_label = TEST_DATA_LABEL,
) -> None:
        """
        Calculate summary statistics from the results of different seeds and print them ordered by the training data label.
        
        Args:
            metric (str): The metric to calculate summary statistics for (e.g., 'accuracy', 'f1_score').
            path_to_results (str): Path to the results directory.
            model_list (list): List of model result file names.
            label_list (list): List of labels corresponding to the models.
            training_data_label (list): List of training data labels.
            test_data_label (list): List of test data labels.
        """
        print("#" * 50)
        print(f"Summary statistics for {metric}")
        print("-" * 40)

        for test_label in set(test_data_label):
                print(f"\n Test Data: {test_label}: \n")
                for idx, model in enumerate(model_list):
                        if test_data_label[idx] == test_label:
                                df = pd.read_csv(path_to_results + model)
                                df = df.loc[df["epoch"] == df["epoch"].max()]
                                mean_value = df[metric].mean()
                                std_value = df[metric].std()
                                print(f"{label_list[idx]} : {mean_value:.4f} ± {std_value:.4f}")
        print("#" * 50)

# %%
calculate_summary_stat('test_accuracy')
calculate_summary_stat('test_f1')
calculate_summary_stat('test_precision_1')
calculate_summary_stat('test_recall_1')
calculate_summary_stat('test_precision_0')
calculate_summary_stat('test_recall_0')
calculate_summary_stat('test_kappa')
# Out:
# ##################################################
# Summary statistics for test_accuracy
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.6200 ± 0.0276
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.7858 ± 0.0309
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6721 ± 0.0292
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8103 ± 0.0234
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.6523 ± 0.0219
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.7191 ± 0.0335
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.5914 ± 0.0343
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7303 ± 0.0212
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.6734 ± 0.0336
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.5528 ± 0.0223
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8213 ± 0.0102
# Finetuned Binary Classifier Trained/Tested Simple : 0.8678 ± 0.0178
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8072 ± 0.0219
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.7996 ± 0.0278
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8248 ± 0.0238
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.8538 ± 0.0257
# ##################################################
# ##################################################
# Summary statistics for test_f1
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.6897 ± 0.0149
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.8034 ± 0.0298
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6842 ± 0.0260
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8103 ± 0.0252
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.7344 ± 0.0184
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.6793 ± 0.0415
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.4331 ± 0.0504
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7289 ± 0.0205
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.6635 ± 0.0353
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.2932 ± 0.0479
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8185 ± 0.0117
# Finetuned Binary Classifier Trained/Tested Simple : 0.8671 ± 0.0180
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8205 ± 0.0196
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.7695 ± 0.0389
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8453 ± 0.0218
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.8438 ± 0.0285
# ##################################################
# ##################################################
# Summary statistics for test_precision_1
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.5857 ± 0.0250
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.7462 ± 0.0476
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6653 ± 0.0465
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8139 ± 0.0364
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.5961 ± 0.0244
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.7968 ± 0.0557
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.7205 ± 0.0935
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7375 ± 0.0350
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.6885 ± 0.0417
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.7112 ± 0.0743
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8357 ± 0.0232
# Finetuned Binary Classifier Trained/Tested Simple : 0.8755 ± 0.0266
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.7711 ± 0.0324
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.9065 ± 0.0244
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.7598 ± 0.0343
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.9091 ± 0.0218
# ##################################################
# ##################################################
# Summary statistics for test_recall_1
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.8402 ± 0.0185
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.8726 ± 0.0325
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.7081 ± 0.0459
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8082 ± 0.0358
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.9578 ± 0.0233
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.5943 ± 0.0497
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.3122 ± 0.0459
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7231 ± 0.0403
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.6424 ± 0.0466
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.1859 ± 0.0364
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8032 ± 0.0301
# Finetuned Binary Classifier Trained/Tested Simple : 0.8598 ± 0.0302
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8779 ± 0.0217
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.6703 ± 0.0554
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.9535 ± 0.0134
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.7885 ± 0.0465
# ##################################################
# ##################################################
# Summary statistics for test_precision_0
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.7074 ± 0.0533
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.8456 ± 0.0329
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6837 ± 0.0314
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8080 ± 0.0339
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.8931 ± 0.0450
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.6737 ± 0.0312
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.5575 ± 0.0305
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7254 ± 0.0280
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.6612 ± 0.0403
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.5292 ± 0.0227
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8089 ± 0.0252
# Finetuned Binary Classifier Trained/Tested Simple : 0.8612 ± 0.0284
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.8566 ± 0.0230
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.7374 ± 0.0348
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.9375 ± 0.0137
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.8120 ± 0.0397
# ##################################################
# ##################################################
# Summary statistics for test_recall_0
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.3973 ± 0.0645
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.7000 ± 0.0559
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6360 ± 0.0779
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.8137 ± 0.0354
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.3438 ± 0.0459
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.8444 ± 0.0538
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.8753 ± 0.0501
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7370 ± 0.0561
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.7050 ± 0.0548
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.9239 ± 0.0243
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.8396 ± 0.0284
# Finetuned Binary Classifier Trained/Tested Simple : 0.8760 ± 0.0305
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.7357 ± 0.0442
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.9298 ± 0.0199
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.6949 ± 0.0459
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.9203 ± 0.0207
# ##################################################
# ##################################################
# Summary statistics for test_kappa
# ----------------------------------------
#
#  Test Data: Shuffled Image:
#
# Binary Classifier Trained Simple/Tested on Shuffled Image : 0.2373 ± 0.0611
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Image : 0.5719 ± 0.0597
# Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.3437 ± 0.0586
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Shuffled Image : 0.6207 ± 0.0468
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Image : 0.3023 ± 0.0381
#
#  Test Data: Shuffled Text:
#
# Binary Classifier Trained Simple/Tested on Shuffled Text : 0.4380 ± 0.0674
# Finetuned Binary Classifier Trained Simple/Tested on Shuffled Text : 0.1864 ± 0.0657
# Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.4598 ± 0.0425
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Shuffled Text : 0.3467 ± 0.0678
# Finetuned Binary Classifier Trained on Shuffled Images/Tested on Shuffled Text : 0.1091 ± 0.0378
#
#  Test Data: Normal Test Data:
#
# Binary Classifier Trained/Testesd Simple : 0.6423 ± 0.0204
# Finetuned Binary Classifier Trained/Tested Simple : 0.7353 ± 0.0355
# Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.6137 ± 0.0435
# Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.5993 ± 0.0552
# Finetuned Binary Classifier Trained on Shuffled Text/Tested on Normal Data : 0.6490 ± 0.0457
# Finetuned Binary Classifier Trained on Shuffled Image/Tested on Normal Data : 0.7077 ± 0.0507
# ##################################################
